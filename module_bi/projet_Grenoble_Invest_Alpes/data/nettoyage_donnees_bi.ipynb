# %% [markdown]
# # 🧼 Nettoyage des fichiers de données bruts – Projet BI

# %%
import pandas as pd
import os
dossier_source = '/home/Inoth/Documents/work/module_bi/projet_Grenoble_Invest_Alpes/data'

# %%
# 🔄 Nettoyage de : BASE ENTREPRISES FILIERES CLES_iiidata.xlsx
df = pd.read_excel(os.path.join(dossier_source, "BASE ENTREPRISES FILIERES CLES_iiidata.xlsx"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "base_entreprises_clean.csv"), index=False)
df.head()
# Out:
#          siret_txt           siret                            société  \
# 0   39939558100032  39939558-00032   STMICROELECTRONICS CROLLES 2 SAS
# 1  '05650171100115   0565017-00115            BECTON DICKINSON FRANCE
# 2   34145938600171  34145938-00171              STMICROELECTRONICS SA
# 3   50494133700017  50494133-00017  STMICROELECTRONICS GRENOBLE 2 SAS
# 4   38471190900034  38471190-00034                             SOITEC
#
#                                       nom_historique naf732  \
# 0                       STMICROELECTRONICS CROLLES 2  2611Z
# 1              BDPHARMA.FR * BECTON DICKINSON France  3250A
# 2        STMICROELECTRONICS CROLLES 1 ex SGS THOMSON  2611Z
# 3  STMICROELECTRONICS 210611E ex 036854N  2 éts  ...  7219Z
# 4                                             SOITEC  2611Z
#
#                     secteur  \
# 0                 Industrie
# 1                 Industrie
# 2                 Industrie
# 3  Services aux entreprises
# 4                 Industrie
#
#                       activité_naf_détaillée_(insee)            enseigne  \
# 0                 Composants et cartes électroniques                 NaN
# 1  Matériel médical, instruments scientifiques et...                 NaN
# 2                 Composants et cartes électroniques  STMICROELECTRONICS
# 3                            Recherche-développement                 NaN
# 4                 Composants et cartes électroniques                 NaN
#
#   année_de_création_de_létablissement           commune  ...  sportdomaine  \
# 0                                2004           CROLLES  ...           NaN
# 1                                1969  LE PONT DE CLAIX  ...           NaN
# 2                                1993           CROLLES  ...           NaN
# 3                                1969          GRENOBLE  ...           NaN
# 4                                1993            BERNIN  ...           NaN
#
#   cleantech  sante                santedomaine  energie  energiedomaine  \
# 0       0.0    0.0                         NaN      0.0             NaN
# 1       0.0    1.0  Drug Delivery System (DDS)      0.0             NaN
# 2       0.0    0.0                         NaN      0.0             NaN
# 3       0.0    0.0                   Pharmacie      0.0             NaN
# 4       0.0    0.0                         NaN      0.0             NaN
#
#   numerique                           num_domaine  chimie chimiedomaine
# 0       1.0  Microélectronique & Nanotechnologies     0.0           NaN
# 1       0.0                                   NaN     0.0           NaN
# 2       1.0  Microélectronique & Nanotechnologies     0.0           NaN
# 3       1.0  Microélectronique & Nanotechnologies     0.0           NaN
# 4       1.0  Microélectronique & Nanotechnologies     0.0           NaN
#
# [5 rows x 26 columns]

# %%
# 🔄 Nettoyage de : donnees_deveco.xlsx
df = pd.read_excel(os.path.join(dossier_source, "donnees_deveco.xlsx"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "donnees_deveco_clean.csv"), index=False)
df.head()
# Out:
#             siret      siren nom_établissement  \
# 0  49910359600239  499103596               NaN
# 1  50983410700013  509834107         @COM.LNCG
# 2  50502954600049  505029546               NaN
# 3  84078568700012  840785687    SUSHI GRENOBLE
# 4  41778726400056  417787264               NaN
#
#                                       nom_entreprise     sigle siège effectif  \
# 0            (LPL) - CENTRALE RHODANIENNE PNEU (CRP)       NaN   non        2
# 1  @ COM. EXPERTISE  RHONE ALPES-SOCIETE D'EXPERT...       NaN   oui       10
# 2                                  @AM.DECO AM. DECO  @AM.DECO   non        3
# 3                                           @KITCHEN       NaN   oui        3
# 4                                             10 COM       NaN   oui        5
#
#              effectifs  date_des_effectifs      chiffre_daffaires  ...  \
# 0           2 salariés              2025.0   Entre 10 M€ et 50 M€  ...
# 1  10 à 19 salarié(e)s              2025.0    Entre 1 M€ et 10 M€  ...
# 2    3 à 5 salarié(e)s              2025.0  Données indisponibles  ...
# 3    3 à 5 salarié(e)s              2025.0  Données indisponibles  ...
# 4    3 à 5 salarié(e)s              2025.0     Entre 0 et 5 000 €  ...
#
#   diffusible numéro                    voie code_postal             commune  \
# 0        oui     18  AVENUE DE LA LOUISIANE       38120  Fontanil-Cornillon
# 1        oui      7          ALLEE DU PEROU       38610              Gières
# 2        oui      1   AVENUE DE L'ILE BRUNE       38120        Saint-Égrève
# 3        oui     19            RUE CHENOISE       38000            Grenoble
# 4        oui     48        RUE DE MORTILLET       38000            Grenoble
#
#   activités_réelles_et_filières zones_géographiques mots-clés commentaires  \
# 0                           NaN                 NaN       NaN          NaN
# 1                           NaN                 NaN       NaN          NaN
# 2                           NaN                 NaN       NaN          NaN
# 3                           NaN                 NaN       NaN          NaN
# 4                           NaN                 NaN       NaN          NaN
#
#           effectifs.1
# 0  1 ou 2 salarié(e)s
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 34 columns]

# %%
# 🔄 Nettoyage de : Cat juridiq II.csv
df = pd.read_csv(os.path.join(dossier_source, "Cat juridiq II.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "cat_juridique_clean.csv"), index=False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 🔄 Nettoyage de : Cat juridiq II.csv
# ----> 2 df = pd.read_csv(os.path.join(dossier_source, "Cat juridiq II.csv"))
#       3 df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
#       4 df.to_csv(os.path.join(dossier_source, "cat_juridique_clean.csv"), index=False)
#
# File ~/Documents/work/module_bi/.dbt-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/work/module_bi/.dbt-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/work/module_bi/.dbt-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/work/module_bi/.dbt-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/Documents/work/module_bi/.dbt-env/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 11: invalid continuation byte

# %%
# 🔄 Nettoyage de : Perimetre economique.xlsx
df = pd.read_excel(os.path.join(dossier_source, "Perimetre economique.xlsx"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "perimetre_economique_clean.csv"), index=False)
df.head()

# %%
# 🔄 Nettoyage de : Perimetre geographique.xlsx
df = pd.read_excel(os.path.join(dossier_source, "Perimetre geographique.xlsx"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "perimetre_geographique_clean.csv"), index=False)
df.head()

# %%
# 🔄 Nettoyage de : Perimetre juridique.xls
df = pd.read_excel(os.path.join(dossier_source, "Perimetre juridique.xls"))
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace("'", '')
df.to_csv(os.path.join(dossier_source, "perimetre_juridique_clean.csv"), index=False)
df.head()
